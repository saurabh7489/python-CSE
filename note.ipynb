# %%
print("hello python")
# Out:
# hello python

# %%
# write a program which take c as i/p and print o/p as ferenhiegh()
c=int(input("enter the celcius value"))
f=c*9/5+32
print("the value of c into f is",f)
# Out:
# the value of c into f is 48.2

# %%
# wap which will take rdius as input and output as circum and ara of cicle
radius=int(input("enter the value of radius:"))
area=22/7*radius**2
circum=2*22/7*radius
print("the area of circle",area
      /"the circumference of circlr",circum)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 5
#       1 # wap which will take rdius as input and output as circum and ara of cicle
#       2 radius=int(input("enter the value of radius:"))
#       3 area=22/7*radius**2
#       4 circum=2*22/7*radius
# ----> 5 print("the area of circle",area
#       6       /"the circumference of circlr",circum)
#
# TypeError: unsupported operand type(s) for /: 'float' and 'str'

# %%
# wap to determine grade based on mark
name=input("enter your name")
print("your name is :",name)
marks=int(input("enter your overall marks"))
if marks>=90:
    print("your grade is GRADE A")
elif marks>=80:
     print("your grade is GRADE B")
elif marks>=70:
    print("your grade is GRADE C")
elif marks>=60:
    print("your grade is GRADE D")
elif marks>=50:
    print("your grade is GRADE E")
else:
    print("YOU ARE A FAILURE")
# Out:
# your name is : ANURAG
# YOU ARE A FAILURE

# %%
# WAP NUMBER IS DIVISIBLE BY BOTH 3 OR 9
num=int(input("enter the number"))
if num%3==0 and num%5==0:
    print("number is divided by 3 and 5")
else:
    print("number is not divded by 3 and 5")
# Out:
# number id divided by 3 and 5

# %%
# wap to find the largest 3 number
num1=int(input("enter the  number 1  "))
num2=int(input("enter the  number 2  "))
num3=int(input("enter the  number 3  "))
print("the number number1=",num1,"number2=",num2,"number3=",num3)
if num1>num2>num3:
    print("number1 is grater =",num1)
elif num2>num1>num3:
    print("number2 is grater =",num2)
else:
    print("number3 is the gratest =",num3)
# Out:
# the number number1= 35 number2= 56 number3= 67
# number3 is the gratest = 67

# %%
# wap to determine the triangle is eq,iso or scalen triangle
sideA=int(input("enter the value of side A"))
sideB=int(input("enter the value of side B"))
sideC=int(input("enter the value of side C"))

if sideA==sideB and sideB==sideC:
    print("the triangle is Equilateral")
elif sideA==sideB or sideB==sideC:
    print("the trianglr is Isoselus")
else :
    print("the triangle is scalus")
# Out:
# the triangle is scalus

# %%
# wap to i/p electricity unit charge and calculate total electric bill
unit=int(input("enter your electric meter unit"))
print("your unit is =",unit)

if unit<=50:
    print("your charges is = ",unit*0.50)
    print("with surcharge =",unit*0.50*1.2)
elif unit<=150:
    print("your charges is =",unit*0.75)
    print("with surcharge =",unit*0.75*1.2)
elif unit<=250:
    print("your charge is = ",unit*1.20)
    print("with surcharge =",unit*1.20*1.2)
elif unit<=450:
    print("your charge is = ",unit*1.50)
    print("with surcharge =",unit*1.50*1.2)
else:
    print("u lil save elec")
# Out:
# your unit is = 300
# your charge is =  450.0
# with surcharge = 540.0

# %%
# wap which accept the km coverd and calcu the bill according

# %%
# wap wchich will chech there is a leep year or not
year=int(input("enter the year"))
print("The year is =",year)
if year%400==0:
    print("the year is leep year")
elif year%4==0 and year%100!=0:
    print("the yera is leep year")
else:
    print("year is not leep year")
# Out:
# The year is = 42
# year is not leep year

# %%
# write a program to check use is able to vote or not
age=int(input("enter your age"))
if age>=18:
    print("you are able to vote")
else:
    print("you can not vote")
# Out:
# you can not vote

# %%
x=6
y=9
z=6
print(id(x),id(y),id(z))
y=7
print(id(x),id(y),id(z))
# Out:
# 140723575674136 140723575674232 140723575674136
# 140723575674136 140723575674168 140723575674136

# %%
name=input("ENTER YOUR NAME")
print(name,/"your name is ",name)
age=int(input("enter your age"))
print("and Your age is ",age)
height=float(input("enter your height"))
print("you have such a great height with",height)
# Out:
# SAURABH your name is  SAURABH
# and Your age is  23
# you have such a great height with 165.0

# %%
# WRITE A PROGRAM to find out the area of rectangle
l=int(input("enter the length of the rectangle"))
print("the length of rectangle is :",l)
w=int(input("enter the Width of the rectangle"))
print("the Width of rectangle is :",w)
A=l*w
print("the area of rectangle is :",A)
# Out:
# the length of rectangle is : 6
# the Width of rectangle is : 9
# the area of rectangle is : 54

# %%
print("hello")

# %%
# range 10,5,-2

# write a program which will print /
#  if the number is divisible by both 3 and 5 from1 to 50


n=int(input("give the number :"))
if n%3==0 and n%5==0:
    print("fizz buzz")
elif n%3==0 and n%5!=0:
    print("fizz")
elif n%3!=0 and n%5==0:
    print("buzz")
else:
    print("bust")
# Out:
# fizz buzz

# %%
# write a program whcich will take input
# from user and print all the fector of this number
n=int(input("enter the number"))
range(i,n+1):
    if n%i==0:
        print(i,end="")
# Out:
#   Cell In[10], line 4
#     range(i,n+1):
#                 ^
# SyntaxError: invalid syntax

# %%
# check that the number is prime or not 
n=int(input("enter the number "))
if n%2==0:
    print("number is prime")
else:
    print("number is odd")
# Out:
# number is prime

# %%
# hey this is the sample code for checking if git is working
# or not
n=int(input("enter the number "))
if(n%2==0):
    print("your number is even")
    for i in range(2,)

# %%
# ncr
n=int(input("give the number "))
if

# %%
# wap
lst=[[1,2,3],[3,4,5],[5,7,3,2]]
lst1=[sum(i) for i in lst]
print(lst1)
# Out:
# [6, 12, 17]

# %%
lst=["red","orange","green","blue","white"]
lst2=["black","yello","green","blue"]
print(lst-lst2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 lst=["red","orange","green","blue","white"]
#       2 lst2=["black","yello","green","blue"]
# ----> 3 print(lst-lst2)
#
# TypeError: unsupported operand type(s) for -: 'list' and 'list'
